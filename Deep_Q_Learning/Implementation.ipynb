# %% [markdown]
# # BT7 - Deep Q-Network (DQN)

# %% [markdown]
# ## Install and import all necessary libraries

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# Out:
# Collecting colabgymrender==1.0.2
#   Downloading colabgymrender-1.0.2.tar.gz (1.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (3.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (1.0.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (4.8.0.76)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (0.0.8)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.5.1)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender==1.0.2) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy->colabgymrender==1.0.2) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2024.6.2)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.2-py3-none-any.whl size=2425 sha256=ae68183536d836bba9531f99c678dbb73df0039183e89cd330666b78bf0d86b9
#   Stored in directory: /root/.cache/pip/wheels/54/1d/51/d65a99106096dd07e3be6f08d5d3c2dd5f26ac98f626e5efc9
# Successfully built colabgymrender
# Installing collected packages: colabgymrender
# Successfully installed colabgymrender-1.0.2

# %%
from colabgymrender.recorder import Recorder
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/skimage/util/dtype.py:27: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/fx/painting.py:7: DeprecationWarning: Please use `sobel` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import sobel

# %%
# install dependencies
# !apt install chromium-browser xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor libfontenc1 libfuse3-3 liblzo2-2 libudev1 libxfont2 libxkbfile1 snapd squashfs-tools
#   systemd-hwe-hwdb udev x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils xserver-common
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser libfontenc1 libfuse3-3 liblzo2-2 libxfont2 libxkbfile1 snapd
#   squashfs-tools systemd-hwe-hwdb udev x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 17 newly installed, 0 to remove and 44 not upgraded.
# Need to get 36.2 MB of archives.
# After this operation, 129 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.3 [595 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.62+22.04 [25.8 MB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [49.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.10 [28.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.10 [863 kB]
# Fetched 36.2 MB in 2s (23.1 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../apparmor_3.0.4-2ubuntu2.3_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.3) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.5-3build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.5-3build1) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 122121 files and directories currently installed.)
# Preparing to unpack .../udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.10.5-1build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.10.5-1build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.62+22.04_amd64.deb ...
# Unpacking snapd (2.62+22.04) ...
# Setting up apparmor (3.0.4-2ubuntu2.3) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up squashfs-tools (1:4.5-3build1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libfuse3-3:amd64 (3.10.5-1build1) ...
# Setting up snapd (2.62+22.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Unit /lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 122351 files and directories currently installed.)
# Preparing to unpack .../00-chromium-browser_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../01-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../02-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../03-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../04-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../05-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../06-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../07-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../08-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../09-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.10_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../10-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.10_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for udev (249.11-0ubuntu3.12) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link

# %% [markdown]
# ## Deep Q-Network implementation

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            nn.Tanh(),
            nn.Linear(64, env.action_space.n)
        )

    def forward(self, state):
        return self.network(state)

    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()

    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)

        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0


        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %% [markdown]
# ## CartPole-v0 Environment

# %%
env = gym.make('CartPole-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# 23.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 50000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 5e-4 # learning rate

memory_size = 50000
min_replay_size = 1000
batch_size = 32

target_update_frequency = 1000 # target network update frequency

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:<ipython-input-9-9a4e4dac0d4a>:44: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   states = torch.tensor(states, dtype=torch.float32)
# Episode: 51 Step: 1000 Average reward: 19.58823529411765
# Episode: 102 Step: 2000 Average reward: 19.67
# Episode: 139 Step: 3000 Average reward: 22.06
# Episode: 172 Step: 4000 Average reward: 25.29
# Episode: 199 Step: 5000 Average reward: 30.3
# Episode: 216 Step: 6000 Average reward: 36.24
# Episode: 232 Step: 7000 Average reward: 41.88
# Episode: 245 Step: 8000 Average reward: 47.45
# Episode: 254 Step: 9000 Average reward: 53.65
# Episode: 264 Step: 10000 Average reward: 61.4
# Episode: 272 Step: 11000 Average reward: 69.71
# Episode: 279 Step: 12000 Average reward: 77.19
# Episode: 284 Step: 13000 Average reward: 85.31
# Episode: 289 Step: 14000 Average reward: 92.95
# Episode: 294 Step: 15000 Average reward: 101.26
# Episode: 299 Step: 16000 Average reward: 109.34
# Episode: 304 Step: 17000 Average reward: 116.7
# Episode: 309 Step: 18000 Average reward: 123.42
# Episode: 314 Step: 19000 Average reward: 130.79
# Episode: 319 Step: 20000 Average reward: 137.74
# Episode: 324 Step: 21000 Average reward: 144.04
# Episode: 329 Step: 22000 Average reward: 151.17
# Episode: 334 Step: 23000 Average reward: 158.26
# Episode: 339 Step: 24000 Average reward: 164.19
# Episode: 344 Step: 25000 Average reward: 170.1
# Episode: 349 Step: 26000 Average reward: 174.7
# Episode: 354 Step: 27000 Average reward: 180.21
# Episode: 359 Step: 28000 Average reward: 185.53
# Episode: 364 Step: 29000 Average reward: 189.73
# Episode: 369 Step: 30000 Average reward: 194.12
# Episode: 374 Step: 31000 Average reward: 197.21
# Episode: 379 Step: 32000 Average reward: 199.67
# Episode: 384 Step: 33000 Average reward: 200.0
# Episode: 389 Step: 34000 Average reward: 200.0
# Episode: 394 Step: 35000 Average reward: 200.0
# Episode: 399 Step: 36000 Average reward: 200.0
# Episode: 404 Step: 37000 Average reward: 200.0
# Episode: 409 Step: 38000 Average reward: 200.0
# Episode: 414 Step: 39000 Average reward: 200.0
# Episode: 419 Step: 40000 Average reward: 200.0
# Episode: 424 Step: 41000 Average reward: 200.0
# Episode: 429 Step: 42000 Average reward: 200.0
# Episode: 434 Step: 43000 Average reward: 200.0
# Episode: 439 Step: 44000 Average reward: 200.0
# Episode: 444 Step: 45000 Average reward: 200.0
# Episode: 449 Step: 46000 Average reward: 200.0
# Episode: 454 Step: 47000 Average reward: 200.0
# Episode: 459 Step: 48000 Average reward: 200.0
# Episode: 464 Step: 49000 Average reward: 200.0
# Episode: 469 Step: 50000 Average reward: 200.0

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# 200.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# ## MountainCar-v0 Environment

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -200.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 325000
epsilon_decay_intervals = 10000
gamma = 0.99
alpha = 5e-4

memory_size = 100000
min_replay_size = 1000
batch_size = 64

target_update_frequency = 1000

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -199.34545454545454
# Episode: 60 Step: 12000 Average reward: -199.4
# Episode: 65 Step: 13000 Average reward: -199.44615384615383
# Episode: 70 Step: 14000 Average reward: -198.8
# Episode: 75 Step: 15000 Average reward: -198.04
# Episode: 80 Step: 16000 Average reward: -198.1625
# Episode: 86 Step: 17000 Average reward: -197.67441860465115
# Episode: 91 Step: 18000 Average reward: -197.34065934065933
# Episode: 96 Step: 19000 Average reward: -197.47916666666666
# Episode: 101 Step: 20000 Average reward: -197.03
# Episode: 106 Step: 21000 Average reward: -197.03
# Episode: 111 Step: 22000 Average reward: -197.03
# Episode: 116 Step: 23000 Average reward: -197.03
# Episode: 121 Step: 24000 Average reward: -196.73
# Episode: 126 Step: 25000 Average reward: -196.73
# Episode: 131 Step: 26000 Average reward: -196.73
# Episode: 136 Step: 27000 Average reward: -196.15
# Episode: 142 Step: 28000 Average reward: -195.99
# Episode: 147 Step: 29000 Average reward: -195.59
# Episode: 152 Step: 30000 Average reward: -195.29
# Episode: 157 Step: 31000 Average reward: -195.65
# Episode: 162 Step: 32000 Average reward: -195.65
# Episode: 167 Step: 33000 Average reward: -195.65
# Episode: 172 Step: 34000 Average reward: -195.95
# Episode: 177 Step: 35000 Average reward: -196.58
# Episode: 182 Step: 36000 Average reward: -196.33
# Episode: 188 Step: 37000 Average reward: -196.35
# Episode: 193 Step: 38000 Average reward: -196.35
# Episode: 198 Step: 39000 Average reward: -196.22
# Episode: 203 Step: 40000 Average reward: -196.77
# Episode: 208 Step: 41000 Average reward: -196.77
# Episode: 213 Step: 42000 Average reward: -196.77
# Episode: 218 Step: 43000 Average reward: -196.48
# Episode: 223 Step: 44000 Average reward: -196.02
# Episode: 228 Step: 45000 Average reward: -196.02
# Episode: 233 Step: 46000 Average reward: -195.69
# Episode: 238 Step: 47000 Average reward: -196.27
# Episode: 243 Step: 48000 Average reward: -196.81
# Episode: 248 Step: 49000 Average reward: -196.83
# Episode: 253 Step: 50000 Average reward: -197.13
# Episode: 258 Step: 51000 Average reward: -197.13
# Episode: 263 Step: 52000 Average reward: -196.74
# Episode: 268 Step: 53000 Average reward: -196.74
# Episode: 273 Step: 54000 Average reward: -196.92
# Episode: 279 Step: 55000 Average reward: -197.41
# Episode: 284 Step: 56000 Average reward: -197.73
# Episode: 289 Step: 57000 Average reward: -197.91
# Episode: 294 Step: 58000 Average reward: -197.46
# Episode: 299 Step: 59000 Average reward: -197.59
# Episode: 304 Step: 60000 Average reward: -197.09
# Episode: 309 Step: 61000 Average reward: -197.09
# Episode: 314 Step: 62000 Average reward: -197.09
# Episode: 319 Step: 63000 Average reward: -197.68
# Episode: 324 Step: 64000 Average reward: -198.14
# Episode: 329 Step: 65000 Average reward: -198.14
# Episode: 334 Step: 66000 Average reward: -198.47
# Episode: 339 Step: 67000 Average reward: -198.47
# Episode: 344 Step: 68000 Average reward: -198.47
# Episode: 349 Step: 69000 Average reward: -198.01
# Episode: 354 Step: 70000 Average reward: -198.01
# Episode: 359 Step: 71000 Average reward: -198.01
# Episode: 364 Step: 72000 Average reward: -198.4
# Episode: 369 Step: 73000 Average reward: -198.4
# Episode: 374 Step: 74000 Average reward: -198.4
# Episode: 379 Step: 75000 Average reward: -198.59
# Episode: 384 Step: 76000 Average reward: -198.59
# Episode: 389 Step: 77000 Average reward: -198.59
# Episode: 394 Step: 78000 Average reward: -199.04
# Episode: 399 Step: 79000 Average reward: -199.04
# Episode: 404 Step: 80000 Average reward: -199.54
# Episode: 409 Step: 81000 Average reward: -199.54
# Episode: 414 Step: 82000 Average reward: -199.54
# Episode: 419 Step: 83000 Average reward: -199.44
# Episode: 424 Step: 84000 Average reward: -199.44
# Episode: 429 Step: 85000 Average reward: -199.44
# Episode: 435 Step: 86000 Average reward: -198.63
# Episode: 440 Step: 87000 Average reward: -198.63
# Episode: 445 Step: 88000 Average reward: -198.4
# Episode: 450 Step: 89000 Average reward: -198.17
# Episode: 455 Step: 90000 Average reward: -198.07
# Episode: 460 Step: 91000 Average reward: -198.07
# Episode: 465 Step: 92000 Average reward: -198.07
# Episode: 470 Step: 93000 Average reward: -197.87
# Episode: 476 Step: 94000 Average reward: -197.39
# Episode: 481 Step: 95000 Average reward: -197.39
# Episode: 486 Step: 96000 Average reward: -197.05
# Episode: 491 Step: 97000 Average reward: -197.01
# Episode: 496 Step: 98000 Average reward: -196.72
# Episode: 501 Step: 99000 Average reward: -196.51
# Episode: 506 Step: 100000 Average reward: -196.51
# Episode: 512 Step: 101000 Average reward: -195.56
# Episode: 517 Step: 102000 Average reward: -194.9
# Episode: 522 Step: 103000 Average reward: -194.49
# Episode: 527 Step: 104000 Average reward: -193.91
# Episode: 533 Step: 105000 Average reward: -193.72
# Episode: 538 Step: 106000 Average reward: -193.04
# Episode: 543 Step: 107000 Average reward: -192.7
# Episode: 549 Step: 108000 Average reward: -192.0
# Episode: 554 Step: 109000 Average reward: -192.38
# Episode: 559 Step: 110000 Average reward: -192.26
# Episode: 564 Step: 111000 Average reward: -192.23
# Episode: 569 Step: 112000 Average reward: -192.18
# Episode: 574 Step: 113000 Average reward: -192.34
# Episode: 579 Step: 114000 Average reward: -192.59
# Episode: 585 Step: 115000 Average reward: -192.03
# Episode: 590 Step: 116000 Average reward: -191.77
# Episode: 595 Step: 117000 Average reward: -191.59
# Episode: 600 Step: 118000 Average reward: -191.49
# Episode: 606 Step: 119000 Average reward: -190.89
# Episode: 611 Step: 120000 Average reward: -191.05
# Episode: 616 Step: 121000 Average reward: -191.63
# Episode: 621 Step: 122000 Average reward: -191.84
# Episode: 627 Step: 123000 Average reward: -191.05
# Episode: 632 Step: 124000 Average reward: -191.36
# Episode: 637 Step: 125000 Average reward: -192.11
# Episode: 642 Step: 126000 Average reward: -191.76
# Episode: 648 Step: 127000 Average reward: -192.27
# Episode: 653 Step: 128000 Average reward: -192.2
# Episode: 658 Step: 129000 Average reward: -191.56
# Episode: 664 Step: 130000 Average reward: -191.15
# Episode: 669 Step: 131000 Average reward: -191.19
# Episode: 674 Step: 132000 Average reward: -191.03
# Episode: 679 Step: 133000 Average reward: -190.78
# Episode: 684 Step: 134000 Average reward: -191.47
# Episode: 690 Step: 135000 Average reward: -190.38
# Episode: 695 Step: 136000 Average reward: -190.33
# Episode: 700 Step: 137000 Average reward: -190.08
# Episode: 705 Step: 138000 Average reward: -190.37
# Episode: 710 Step: 139000 Average reward: -190.62
# Episode: 716 Step: 140000 Average reward: -190.7
# Episode: 721 Step: 141000 Average reward: -191.14
# Episode: 726 Step: 142000 Average reward: -191.81
# Episode: 731 Step: 143000 Average reward: -192.14
# Episode: 736 Step: 144000 Average reward: -192.59
# Episode: 741 Step: 145000 Average reward: -192.77
# Episode: 746 Step: 146000 Average reward: -192.98
# Episode: 751 Step: 147000 Average reward: -193.17
# Episode: 757 Step: 148000 Average reward: -193.02
# Episode: 762 Step: 149000 Average reward: -193.74
# Episode: 767 Step: 150000 Average reward: -193.83
# Episode: 772 Step: 151000 Average reward: -193.85
# Episode: 777 Step: 152000 Average reward: -194.17
# Episode: 782 Step: 153000 Average reward: -194.32
# Episode: 787 Step: 154000 Average reward: -195.43
# Episode: 792 Step: 155000 Average reward: -195.43
# Episode: 797 Step: 156000 Average reward: -195.98
# Episode: 802 Step: 157000 Average reward: -196.45
# Episode: 807 Step: 158000 Average reward: -196.45
# Episode: 812 Step: 159000 Average reward: -196.39
# Episode: 817 Step: 160000 Average reward: -196.71
# Episode: 822 Step: 161000 Average reward: -196.71
# Episode: 827 Step: 162000 Average reward: -196.97
# Episode: 832 Step: 163000 Average reward: -197.25
# Episode: 838 Step: 164000 Average reward: -196.83
# Episode: 843 Step: 165000 Average reward: -196.6
# Episode: 848 Step: 166000 Average reward: -196.57
# Episode: 853 Step: 167000 Average reward: -196.9
# Episode: 858 Step: 168000 Average reward: -197.19
# Episode: 863 Step: 169000 Average reward: -197.0
# Episode: 869 Step: 170000 Average reward: -196.44
# Episode: 874 Step: 171000 Average reward: -195.8
# Episode: 879 Step: 172000 Average reward: -195.33
# Episode: 884 Step: 173000 Average reward: -195.34
# Episode: 889 Step: 174000 Average reward: -194.86
# Episode: 895 Step: 175000 Average reward: -193.81
# Episode: 901 Step: 176000 Average reward: -192.42
# Episode: 906 Step: 177000 Average reward: -191.51
# Episode: 912 Step: 178000 Average reward: -191.03
# Episode: 917 Step: 179000 Average reward: -190.18
# Episode: 923 Step: 180000 Average reward: -188.98
# Episode: 929 Step: 181000 Average reward: -187.37
# Episode: 934 Step: 182000 Average reward: -186.22
# Episode: 940 Step: 183000 Average reward: -185.82
# Episode: 946 Step: 184000 Average reward: -184.95
# Episode: 951 Step: 185000 Average reward: -183.84
# Episode: 957 Step: 186000 Average reward: -182.39
# Episode: 962 Step: 187000 Average reward: -181.75
# Episode: 968 Step: 188000 Average reward: -181.12
# Episode: 973 Step: 189000 Average reward: -181.18
# Episode: 979 Step: 190000 Average reward: -180.9
# Episode: 984 Step: 191000 Average reward: -180.37
# Episode: 990 Step: 192000 Average reward: -179.74
# Episode: 995 Step: 193000 Average reward: -180.05
# Episode: 1001 Step: 194000 Average reward: -180.18
# Episode: 1006 Step: 195000 Average reward: -180.8
# Episode: 1011 Step: 196000 Average reward: -180.45
# Episode: 1017 Step: 197000 Average reward: -180.98
# Episode: 1022 Step: 198000 Average reward: -180.88
# Episode: 1028 Step: 199000 Average reward: -181.48
# Episode: 1033 Step: 200000 Average reward: -182.4
# Episode: 1038 Step: 201000 Average reward: -182.46
# Episode: 1044 Step: 202000 Average reward: -183.49
# Episode: 1049 Step: 203000 Average reward: -183.4
# Episode: 1055 Step: 204000 Average reward: -184.22
# Episode: 1060 Step: 205000 Average reward: -185.14
# Episode: 1065 Step: 206000 Average reward: -184.41
# Episode: 1071 Step: 207000 Average reward: -185.07
# Episode: 1076 Step: 208000 Average reward: -185.23
# Episode: 1081 Step: 209000 Average reward: -185.72
# Episode: 1086 Step: 210000 Average reward: -185.99
# Episode: 1091 Step: 211000 Average reward: -186.62
# Episode: 1096 Step: 212000 Average reward: -187.49
# Episode: 1102 Step: 213000 Average reward: -188.4
# Episode: 1107 Step: 214000 Average reward: -187.64
# Episode: 1113 Step: 215000 Average reward: -187.59
# Episode: 1118 Step: 216000 Average reward: -187.53
# Episode: 1123 Step: 217000 Average reward: -188.8
# Episode: 1128 Step: 218000 Average reward: -189.06
# Episode: 1134 Step: 219000 Average reward: -189.04
# Episode: 1139 Step: 220000 Average reward: -188.43
# Episode: 1145 Step: 221000 Average reward: -188.08
# Episode: 1150 Step: 222000 Average reward: -188.68
# Episode: 1155 Step: 223000 Average reward: -188.82
# Episode: 1160 Step: 224000 Average reward: -188.6
# Episode: 1166 Step: 225000 Average reward: -189.61
# Episode: 1171 Step: 226000 Average reward: -189.97
# Episode: 1176 Step: 227000 Average reward: -189.72
# Episode: 1181 Step: 228000 Average reward: -189.55
# Episode: 1186 Step: 229000 Average reward: -189.54
# Episode: 1191 Step: 230000 Average reward: -190.11
# Episode: 1196 Step: 231000 Average reward: -190.04
# Episode: 1201 Step: 232000 Average reward: -190.39
# Episode: 1206 Step: 233000 Average reward: -191.28
# Episode: 1211 Step: 234000 Average reward: -192.07
# Episode: 1216 Step: 235000 Average reward: -192.6
# Episode: 1221 Step: 236000 Average reward: -193.19
# Episode: 1226 Step: 237000 Average reward: -193.34
# Episode: 1231 Step: 238000 Average reward: -193.81
# Episode: 1236 Step: 239000 Average reward: -195.04
# Episode: 1241 Step: 240000 Average reward: -196.03
# Episode: 1246 Step: 241000 Average reward: -196.66
# Episode: 1251 Step: 242000 Average reward: -197.31
# Episode: 1256 Step: 243000 Average reward: -197.54
# Episode: 1261 Step: 244000 Average reward: -198.1
# Episode: 1266 Step: 245000 Average reward: -198.38
# Episode: 1271 Step: 246000 Average reward: -198.55
# Episode: 1276 Step: 247000 Average reward: -199.15
# Episode: 1281 Step: 248000 Average reward: -199.57
# Episode: 1286 Step: 249000 Average reward: -199.93
# Episode: 1291 Step: 250000 Average reward: -199.93
# Episode: 1296 Step: 251000 Average reward: -200.0
# Episode: 1301 Step: 252000 Average reward: -200.0
# Episode: 1306 Step: 253000 Average reward: -200.0
# Episode: 1311 Step: 254000 Average reward: -200.0
# Episode: 1316 Step: 255000 Average reward: -200.0
# Episode: 1321 Step: 256000 Average reward: -200.0
# Episode: 1326 Step: 257000 Average reward: -200.0
# Episode: 1331 Step: 258000 Average reward: -200.0
# Episode: 1336 Step: 259000 Average reward: -200.0
# Episode: 1341 Step: 260000 Average reward: -200.0
# Episode: 1346 Step: 261000 Average reward: -200.0
# Episode: 1351 Step: 262000 Average reward: -200.0
# Episode: 1356 Step: 263000 Average reward: -200.0
# Episode: 1361 Step: 264000 Average reward: -200.0
# Episode: 1366 Step: 265000 Average reward: -200.0
# Episode: 1371 Step: 266000 Average reward: -200.0
# Episode: 1376 Step: 267000 Average reward: -200.0
# Episode: 1381 Step: 268000 Average reward: -200.0
# Episode: 1386 Step: 269000 Average reward: -200.0
# Episode: 1391 Step: 270000 Average reward: -200.0
# Episode: 1396 Step: 271000 Average reward: -200.0
# Episode: 1401 Step: 272000 Average reward: -200.0
# Episode: 1406 Step: 273000 Average reward: -200.0
# Episode: 1411 Step: 274000 Average reward: -200.0
# Episode: 1416 Step: 275000 Average reward: -200.0
# Episode: 1421 Step: 276000 Average reward: -200.0
# Episode: 1426 Step: 277000 Average reward: -200.0
# Episode: 1431 Step: 278000 Average reward: -200.0
# Episode: 1436 Step: 279000 Average reward: -200.0
# Episode: 1441 Step: 280000 Average reward: -200.0
# Episode: 1446 Step: 281000 Average reward: -200.0
# Episode: 1451 Step: 282000 Average reward: -200.0
# Episode: 1456 Step: 283000 Average reward: -200.0
# Episode: 1461 Step: 284000 Average reward: -200.0
# Episode: 1466 Step: 285000 Average reward: -200.0
# Episode: 1471 Step: 286000 Average reward: -200.0
# Episode: 1476 Step: 287000 Average reward: -200.0
# Episode: 1481 Step: 288000 Average reward: -200.0
# Episode: 1486 Step: 289000 Average reward: -200.0
# Episode: 1491 Step: 290000 Average reward: -200.0
# Episode: 1496 Step: 291000 Average reward: -200.0
# Episode: 1501 Step: 292000 Average reward: -200.0
# Episode: 1506 Step: 293000 Average reward: -200.0
# Episode: 1511 Step: 294000 Average reward: -200.0
# Episode: 1516 Step: 295000 Average reward: -200.0
# Episode: 1521 Step: 296000 Average reward: -200.0
# Episode: 1526 Step: 297000 Average reward: -200.0
# Episode: 1532 Step: 298000 Average reward: -199.17
# Episode: 1537 Step: 299000 Average reward: -198.54
# Episode: 1543 Step: 300000 Average reward: -197.17
# Episode: 1548 Step: 301000 Average reward: -196.14
# Episode: 1554 Step: 302000 Average reward: -195.04
# Episode: 1560 Step: 303000 Average reward: -193.5
# Episode: 1566 Step: 304000 Average reward: -191.55
# Episode: 1572 Step: 305000 Average reward: -189.62
# Episode: 1577 Step: 306000 Average reward: -188.15
# Episode: 1583 Step: 307000 Average reward: -186.37
# Episode: 1589 Step: 308000 Average reward: -184.42
# Episode: 1596 Step: 309000 Average reward: -181.29
# Episode: 1602 Step: 310000 Average reward: -178.69
# Episode: 1610 Step: 311000 Average reward: -173.13
# Episode: 1618 Step: 312000 Average reward: -167.58
# Episode: 1625 Step: 313000 Average reward: -163.55
# Episode: 1632 Step: 314000 Average reward: -159.52
# Episode: 1639 Step: 315000 Average reward: -157.42
# Episode: 1646 Step: 316000 Average reward: -154.79
# Episode: 1653 Step: 317000 Average reward: -151.38
# Episode: 1660 Step: 318000 Average reward: -149.63
# Episode: 1668 Step: 319000 Average reward: -145.56
# Episode: 1676 Step: 320000 Average reward: -142.01
# Episode: 1683 Step: 321000 Average reward: -140.51
# Episode: 1690 Step: 322000 Average reward: -139.48
# Episode: 1696 Step: 323000 Average reward: -138.95
# Episode: 1703 Step: 324000 Average reward: -138.73
# Episode: 1709 Step: 325000 Average reward: -140.73

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# -157.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:  90%|████████▉ | 143/159 [00:00<00:00, 287.70it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./video/1717947736.175151.mp4, 720000 bytes wanted but 0 bytes read,at frame 158/159, at time 5.27/5.27 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
